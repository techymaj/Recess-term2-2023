# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# Control Display of seaborn data
pd.options.display.max_columns=50
sns.set(style="darkgrid", rc={"axes.facecolor": "#CAF1DE"})

# %%
# read_csv() function returns a DataFrame object.
ds = pd.read_csv('bse_dataset4.csv')
ds
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
df = pd.DataFrame(ds)
df
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'gender', 'Age', 'emotion', 'YOB', 'CGPA',
#        'Do you have a Girl Friend or BOY Friend', 'Do you have Depression?',
#        'Do you have Anxiety?', 'Do you have Panic attack?',
#        'Did you have seek any specialist for a treatment? ', 'Duration',
#        'Pulse', 'Maxpulse', 'Calories'],
#       dtype='object')

# %%
ds.dropna()
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
# inplace=True means that the changes are saved to the df right away
ds.dropna(inplace=True)

# %%
df.fillna(100, inplace=True)
print(df)
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
# search for columns with 100
df[df == 100].count()
# Out:
# Timestamp                                              0
# gender                                                 0
# Age                                                    0
# emotion                                                0
# YOB                                                    0
# CGPA                                                   0
# Do you have a Girl Friend or BOY Friend                0
# Do you have Depression?                                0
# Do you have Anxiety?                                   0
# Do you have Panic attack?                              0
# Did you have seek any specialist for a treatment?      0
# Duration                                               0
# Pulse                                                 17
# Maxpulse                                               3
# Calories                                               0
# dtype: int64

# %%
# display the cells in Maxpulse with 100
df[df['Maxpulse'] == 100]
# Out:
#                Timestamp  gender   Age     emotion   YOB              CGPA  \
# 93   05/07/2023 09:54:13    Male  29.0     Hopeful  1994  I don't know yet
# 102  05/07/2023 09:39:47  Female  23.0      Happy   2000               3.8
# 103  05/07/2023 09:39:49  female  21.0  irritated   2001              3.88
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# 93               Sure, multiple girlfriends                      No
# 102                                      No                      No
# 103                                      no                      no
#
#     Do you have Anxiety? Do you have Panic attack?  \
# 93                    No                        No
# 102                   No                        No
# 103                   no                      yes
#
#     Did you have seek any specialist for a treatment?   Duration  Pulse  \
# 93                                                  No        15     80
# ...

# %%
# to_string() is used to print the entire DataFrame
print(df.to_string())
# Out:
#                Timestamp         gender   Age               emotion            YOB              CGPA Do you have a Girl Friend or BOY Friend Do you have Depression? Do you have Anxiety? Do you have Panic attack? Did you have seek any specialist for a treatment?   Duration  Pulse  Maxpulse  Calories
# 0    05/07/2023 09:38:39           Male  21.0               Content           2002              4.22                                      No                      No                  Yes                       Yes                                                Yes        60    110       130     409.1
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird           2100               8.9                                     Yes                     Yes                  Yes                       Yes                                                 No        60    117       145     479.0
# ...

# %%
# caclulate the mean of the Maxpulse column
mean_calories = df['Calories'].mean()
# print the mean of the Maxpulse column
mean_calories
# Out:
# 371.91687500000006

# %%
mean_max_pulse = df['Maxpulse'].mean()
mean_max_pulse
# Out:
# 134.3

# %%
# calculate the median
median_calories = df['Calories'].median()
median_calories
# Out:
# 317.85

# %% [markdown]
# ###  Core of data preparation and preprocessing. Handle the following:
# - Empty cells
# - Wrong formats
# - Wrong data
# - Duplicates

# %%
# get the median for calories
medain_calories = df['Calories'].median()
# medain_calories
filled_median = df.fillna(medain_calories, inplace=True)

# print all the rows with filled median
print(df['Calories'].to_string())
# Out:
# 0       409.1
# 1       479.0
# 2       340.0
# 3       282.4
# 4       406.0
# 5       300.0
# 6       374.0
# 7       253.3
# 8       195.1
# 9       269.0
# 10      329.3
# 11      269.0
# 12      345.3
# 13      379.3
# 14      275.0
# 15      215.2
# 16      300.0
# 17      318.6
# 18      323.0
# 19      243.0
# 20      364.2
# 21      282.0
# 22      300.0
# 23      246.0
# 24      334.5
# 25      250.0
# 26      241.0
# 27      318.6
# 28      280.0
# 29      380.3
# 30      243.0
# 31      180.1
# 32      299.0
# 33      223.0
# 34      361.0
# 35      415.0
# 36      300.0
# 37      300.0
# 38      300.0
# 39      266.0
# 40      180.1
# 41      286.0
# 42      329.4
# 43      400.0
# 44      397.0
# 45      273.0
# 46      387.6
# 47      300.0
# 48      298.0
# 49      397.6
# 50      380.2
# 51      643.1
# 52      263.0
# 53      486.0
# 54      238.0
# 55      450.7
# 56      413.0
# 57      305.0
# 58      226.4
# 59      321.0
# 60     1376.0
# 61     1034.4
# ...

# %% [markdown]
# ## Exercise 1: Calculate mode on age

# %%
# calculate the mode for age
mode_age = df['Age'].mode()
mode_age
# Out:
# 0    21.0
# Name: Age, dtype: float64

# %% [markdown]
# ###
age               emotion            YOB              CGPA Do you have a Girl Friend or BOY Friend Do you have Depression? Do you have Anxiety? Do you have Panic attack? Did you have seek any specialist for a treatment?   Duration  Pulse  Maxpulse  Calories
# 0    05/07/2023 09:38:39           Male   21.0               Content           2002              4.22                                      No                      No                  Yes                       Yes                                                Yes        60    110       130     409.1
# 1    05/07/2023 09:38:57  Marabou stock   45.0                 Weird           2100               8.9                                     Yes                     Yes                  Yes                       Yes                                                 No        60    117       145     479.0
# ...

# %%
backup_ds = ds.copy()
backup_ds
# Out:
#                          Timestamp         gender   Age  emotion   YOB  CGPA  \
# 0              05/07/2023 09:38:39           Male  21.0  Content  2002  4.22
# 1              05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100   8.9
# 2              05/07/2023 09:39:09        Female   20.0    Happy  2002  3.98
# 3              05/07/2023 09:39:12           Male  21.0    Happy  2003  4.37
# 4              05/07/2023 09:39:14         Female  21.0    Happy  2002  3.63
# ...                            ...            ...   ...      ...   ...   ...
# marabou stock                  NaN          Other   NaN      NaN   NaN   NaN
# female                         NaN          Other   NaN      NaN   NaN   NaN
# female                         NaN          Other   NaN      NaN   NaN   NaN
# yes                            NaN          Other   NaN      NaN   NaN   NaN
# m                              NaN          Other   NaN      NaN   NaN   NaN
#
# ...

# %%
# iterate through the rows of the gender column
for i, x in enumerate(ds['gender']):
    # convert the gender to lower case
    x = x.lower()
    # remove white spaces
    x = x.strip()
    # check if x is not among the values in the list
    if x not in ['m', 'f', 'male', 'female']:
        # replace the value with other
        ds.loc[i, 'gender'] = 'other'

print(ds['gender'].to_string())
# Out:
#                Timestamp   gender   Age  emotion   YOB  CGPA  \
# 0    05/07/2023 09:38:39     Male  21.0  Content  2002  4.22
# 1    05/07/2023 09:38:57    other  45.0    Weird  2100   8.9
# 2    05/07/2023 09:39:09  Female   20.0    Happy  2002  3.98
# 3    05/07/2023 09:39:12     Male  21.0    Happy  2003  4.37
# 4    05/07/2023 09:39:14   Female  21.0    Happy  2002  3.63
# ..                   ...      ...   ...      ...   ...   ...
# 178                  NaN    other   NaN      NaN   NaN   NaN
# 179                  NaN    other   NaN      NaN   NaN   NaN
# 180                  NaN    other   NaN      NaN   NaN   NaN
# 181                  NaN    other   NaN      NaN   NaN   NaN
# 182                  NaN    other   NaN      NaN   NaN   NaN
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# 0                                        No                      No
# 1                                       Yes                     Yes
# ...

# %%
new_ds = pd.read_csv('bse_dataset4.csv')
new_ds
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
# iterate through the rows of the gender column
for i, x in enumerate(new_ds['gender']):
    # convert the gender to lower case
    x = x.lower()
    # remove white spaces
    x = x.strip()
    # check if x is not among the values in the list
    if x not in ['m', 'f', 'male', 'female']:
        # replace the value with other
        new_ds.loc[i, 'gender'] = 'other'

print(new_ds['gender'].to_string())
# Out:
# 0         Male
# 1        other
# 2      Female
# 3         Male
# 4       Female
# 5       Female
# 6       female
# 7      Female
# 8         Male
# 9       Female
# 10        Male
# 11      Female
# 12        Male
# 13        MALE
# 14      FEMALE
# 15        Male
# 16      Female
# 17        Male
# 18        Male
# 19        Male
# 20      FEMALE
# 21        Male
# 22        Male
# 23        male
# 24      Female
# 25      Female
# 26        Male
# 27        Male
# 28     Female
# 29        Male
# 30        Male
# 31      Female
# 32        male
# 33        male
# 34        Male
# 35        Male
# 36        male
# 37        Male
# 38      Female
# 39        male
# 40     Female
# 41        male
# 42        male
# 43        Male
# 44        Male
# 45      female
# 46        Male
# 47     Female
# 48        Male
# 49        Male
# 50        Male
# 51        Male
# 52      female
# 53        Male
# 54        Male
# 55        Male
# 56     Female
# 57       other
# 58        male
# ...
